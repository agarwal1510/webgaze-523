# %%
import pandas as pd
import matplotlib
import warnings
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import mlab
import math
import seaborn as sns

# %%
df_3g = pd.DataFrame(columns=['sitename','category','median_scroll', 'size', 'onload_uplt', 'implicit_uplt', 'median_uplt'])
df_scroll = pd.read_csv('max_pct_viewports_scrolled_multi_3g.csv')
df_size = pd.read_csv('mobile_screens_multi_3g.csv')
df_onload = pd.read_csv('mobile_scroll_screen_viewports_onload_3g_max.csv')
df_implicit = pd.read_csv('scroll_implicit_uplt_multi_3g_median.csv')
df_median = pd.read_csv('scroll_uplt_multi_3g_median.csv')


df_3g['sitename'] = df_scroll['sitename']

# df_3g = df_3g.sort_values('sitename')
# df_onload = df_onload.sort_values('sitename')
# df_implicit = df_implicit.sort_values('sitename')
# df_median = df_median.sort_values('sitename')
# df_size = df_size.sort_values('site')
# df_size = df_size.reset_index(drop=True)

df_3g['onload_uplt'] = df_onload['value']
df_3g['implicit_uplt'] = df_implicit['value']
df_3g['median_uplt'] = df_median['value']
df_3g['size'] = df_size['numScreens']
df_3g['category'] = df_onload['category']

df_scroll['mean'] = df_scroll.mean(axis=1)
df_3g['median_scroll'] = df_scroll['mean']

df_3g
# Out:
#               sitename        category  median_scroll   size  onload_uplt  \
# 0             aarp.org            Home       0.311092  17.24        64770
# 1              acm.org        Computer       0.308415  22.01        83924
# 2               adf.ly        Computer       0.496194   3.65         9419
# 3            alexa.com        Computer       0.425713   9.45        56511
# 4           amazon.com        Shopping       0.368232   7.59         5996
# 5              att.com        Business       0.393314   7.03        21469
# 6       blackboard.com       Reference       0.382762  10.45        45542
# 7   bleacherreport.com          Sports       0.372403  55.06       120000
# 8        bloomberg.com            News       0.439755  11.05       100994
# 9           carfax.com            Home       0.487821   1.86         6334
# 10  cartoonnetwork.com  Kids and Teens       0.443125   4.96        34324
# 11            citi.com        Business       0.459759   7.29        13053
# 12            cnet.com        Computer       0.331677  15.90         4915
# 13          costco.com        Shopping       0.531878   5.12        41371
# 14           diply.com        Computer       0.348232  10.13        19107
# 15            ebay.com        Shopping       0.517612   2.66         3212
# 16            etsy.com        Shopping       0.388131   9.99        19359
# 17           heart.org          Health       0.397609   7.02        36932
# 18         history.com  Kids and Teens       0.425509   8.43        18885
# 19           imgur.com        Computer       0.253157  21.92        12810
# 20      kongregate.com           Games       0.487592   4.49         6010
# 21          kotaku.com           Games       0.314108  24.18        53728
# 22      lifehacker.com            Home       0.274859  24.85        37870
# 23           macys.com        Shopping       0.474576   5.25        30723
# 24        marriott.com    Recreational       0.484635   7.97        32041
# 25       mathworks.com         Science       0.431444   7.25        14495
# 26         mozilla.org        Computer       0.459764   6.82         8473
# 27         nytimes.com            News       0.280224  28.74        95176
# 28           opera.com        Computer       0.509480   2.68         5516
# 29       overstock.com        Shopping       0.434330   7.99        12237
# 30     playstation.com           Games       0.511620   6.57        30074
# 31          ranker.com            News       0.314335  12.19        12923
# 32      rantsports.com          Sports       0.331702  11.36        87959
# 33     retailmenot.com        Shopping       0.431933   8.12         8108
# 34         samsung.com        Business       0.442880   4.43        13164
# 35          scribd.com        Business       0.469967   6.31        20190
# 36          sfgate.com            News       0.228911  35.11        47868
# 37       sitepoint.com       Reference       0.345148  14.08        33106
# 38      slideshare.net        Computer       0.289986  19.27         4825
# 39        squareup.com        Business       0.287054  14.98        21783
# 40         stubhub.com        Shopping       0.420281   6.60         6960
# 41             ted.com         Science       0.431548   9.61        26951
# 42     theatlantic.com            News       0.320667  19.28        94259
# 43        theonion.com        Shopping       0.336826  25.31        45117
# 44           vimeo.com        Computer       0.522335   4.88        11153
# 45  weightwatchers.com          Health       0.380889   7.30        80753
# 46      whitehouse.gov         Society       0.462242   6.87        11571
# 47           wiley.com        Business       0.560376   6.46        27362
# 48      wunderlist.com            Home       0.415007   8.10        11372
# 49         youtube.com        Computer       0.530153   2.82        12955
#
#     implicit_uplt  median_uplt
# 0         12627.0      16758.5
# 1          5751.0      11961.0
# 2          8075.5       8075.5
# 3         15395.0      20994.5
# 4          8355.0       9364.5
# 5         18150.5      19212.5
# 6         12017.5      16812.5
# 7         10121.0      17784.5
# 8         16056.0      26220.0
# 9         10482.5      10482.5
# 10        16974.5      17281.5
# 11         9183.0      14641.5
# 12         5980.5       8415.5
# 13        14332.5      22270.0
# 14        13800.5      15231.5
# 15         5389.0       6331.5
# 16        14987.0      14987.0
# 17        14579.5      26547.5
# 18         7564.5       8557.0
# 19        16302.5      22493.5
# 20         8215.0       8327.0
# 21         9283.0      12666.5
# 22         7561.0      12474.5
# 23        24528.5      25190.0
# 24         9988.5      20742.5
# 25        10742.0      11169.0
# 26         9381.5       9381.5
# 27         9401.5      17145.0
# 28         5871.5       5871.5
# 29         5506.5       6961.5
# 30        20543.5      27840.5
# 31         8201.0       8953.5
# 32         9195.0      11691.0
# 33         8211.5       9104.5
# 34         8262.5      12877.5
# 35         7969.5      11988.5
# 36        25461.0      28567.5
# 37         7018.0      10515.0
# 38         9235.5      11599.5
# 39        12139.5      12856.5
# 40        14072.5      14281.0
# 41         7855.0      14892.0
# 42        15746.5      19849.5
# 43         8273.0      15431.5
# 44         8647.0      10495.5
# 45        40092.0      47702.5
# 46         7804.5       8947.5
# 47        16047.0      27364.0
# 48         8620.0       8882.5
# 49        10412.0      13097.5

# %%
df_cor = {'Scroll':df_3g['median_scroll'], 'site_size':df_3g['size'], 
          'onLoad_uplt':df_3g['onload_uplt'], 'Implicit_uplt':df_3g['implicit_uplt'], 
          'Median_uplt':df_3g['median_uplt']}
df_cor = pd.DataFrame(df_cor).astype('float64')
r = df_cor.corr()
sns.heatmap(r, fmt=".2g", annot=True, cmap="viridis", linewidths=.8)
plt.show()
